# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer as SIA
import pandas as pd
pd.set_option('display.max_colwidth', -1)

# %%
data = pd.read_csv("../Dumps Twitter/bullish_tweets.csv")
columns_to_drop = ["Created At","Verified User","Reply Tweet",
                   "Reply To User ID","Original Tweet","Tweet ID",
                   "Favorite Count"
                  ]
data.drop(columns_to_drop, axis=1, inplace=True)

# %%
analyzer = SIA()
data["Sentiment"] = data.apply(lambda row: analyzer.polarity_scores(row["Status"])["compound"], axis=1)
errors = data.loc[data["Sentiment"] < 0]
nb_errors = errors.shape[0]
printmd("Accuracy : {:2.2%} ({} errors)".format(1 - nb_errors/data.shape[0], nb_errors))
# Out:
# Accuracy : 90.79% (332 errors)

# %% [markdown]
# # Errors : Bullish tweets with a negative sentiment

# %%
display(errors)
# Out:
#              Username  \
# 3     ALQOCOIN
# 13    LitecoinNewsCOM
# 25    WindCoin
# 33    CryptoKirby
# 36    LucydLtd
# 43    notsofast
# 54    snb_world
# 56    pirapira
# 65    Useless_Token
# 82    starsoup7
# 88    BTCDJS
# 111   Martin_AIM_77
# 130   AMLT_Token
# 133   moneytrigz
# 138   StartUscc
# 154   gladiusIO
# 167   gladiusIO
# 173   LevelNetwork
# 180   3L10n
# 197   CroMhub
# 212   Bankeracom
# 220   REGA_fintech
# 241   manuelinoino
# 242   sytaylor
# 249   dentcoin
# 281   bullishgentlemn
# 282   deenyotweets
# 285   Codiox
# 286   RandyHilarski
# 334   MrJozza
# ...       ...
# 3422  adam3us
# 3424  adam3us
# 3438  Cointelegraph
# 3458  Cointelegraph
# 3509  wavesplatform
# 3520  wax_io
# 3521  lopp
# 3525  cburniske
# 3528  lopp
# 3532  lopp
# 3535  naval
# 3542  maxkeiser
# 3544  maxkeiser
# 3545  lopp
# 3546  maxkeiser
# 3547  maxkeiser
# 3549  lopp
# 3551  maxkeiser
# 3559  lopp
# 3561  _Kevin_Pham
# 3562  _Kevin_Pham
# 3563  _Kevin_Pham
# 3564  _Kevin_Pham
# 3566  _Kevin_Pham
# 3576  Ripple
# 3580  Ripple
# 3581  Ripple
# 3595  NEMofficial
# 3596  alansilbert
# 3597  TuurDemeester
#
#                                                                                                                                                                                                                                                                                                                                                      Status  \
# 3     We are officially listed on crypto-bridge now! http://crypto-bridge.org  Trade $alqo now with low fees! #followtheorangerabbit #cryptocurrency #bitcoin #Ethereum $btc $eth $neo $ltc $dash
# 13    #Hodl your #Litecoin or u will regret selling .. patience .. our time is coming sooner than you thinkpic.twitter.com/uiGqzm8GsZ
# 25    We are having a bit of a problem with distribution of token, because kittens are clogging the network, crazy, we know:) As soon network is faster we start! #WindCoin #Airdrop
# 33    ALERT$20K #Bitcoin by Christmas doesn't seem like an impossibility.I'm BULLISH! $btc $ltc $eth $neo $xrp $omg $qtum $lsk $etc $ok $dash $strat $pay $xmr $vtc $xlm $grs $kmd $adx $xvg $pkb $ada $eos $salt $cvc $bat $dgb $waves $sc $nxt $snt $doge $mtl $xzcpic.twitter.com/NKSRXAnu48
# 36    Hey Lucyd dreamers! If you haven't already, please follow us on Instagram for more updates! https://www.instagram.com/lucydltd/  #smartglasses#token #tokensale #LCD #Ether #cointelegraph #tokenized #tokencoin #IoE #gadgets #latest #electronics #altcoins #altcoin #programmers #AR
# 43    The $DAO was a 2016 record-raising ICO where its funds could crowdfund other projects, or split into smaller DAOs in disagreement. A guy figured out how to recursively split the DAO & pay himself ALL. $ETH forked to take back what he took. $ETC is the fork where he got to keep ithttps://twitter.com/Whalebearbull/status/938488982308114433 …
# 54    SNB tokens will be sold till December 30.Please, familiarize yourself with the step-by-step instructions on how to buy ETH. If you have any troubles buying ETH, you can write an email to us to describe what exactly is going wrong, and we will help you.#ICO #token #snb
# 56    An #ethereum block 2 yrs. ago says "ganz viele Katzen" (totally many cats) https://etherchain.org/block/79183  , prophecy fulfilled.
# 65    $UETL has submitted our paid application to @YobitExchange this morning!The #UselessArmy will now have yet another exchange to add to the list!Check out our $Useless website.http://www.uselessethtokenlite.com Together we can defeat #CryptoKitties !#blockchain #crypto $btc $eth $ltc pic.twitter.com/XpXMhVqVgy
# 82    Day 2 of @ConsenSys #designthinking  workshop with @infura_io @metamask_io @uport_me @trufflesuite and they are killing it #blockchain #Ethereum pic.twitter.com/eoeh44MKHj
# 88    How many times has there been FUD about multiple Crypto projects including BTC. And has it really mattered? Because I recall $ETH $DASH $IOTA $BTC all had some sort of negative opinions shared about them when the prices were much lower than they are today. Look at them now.
# 111   my Crypto is booming while my AIM is falling! why can’t they go in pair! I know, because of MM’s & dodgy brokers!#cryptocurrency $btc $eth
# 130   "Path to anti-money laundering & counter terrorist financing" Read up on another  @AMLT_Token #TokenSale review in @Medium http://ift.tt/2B1M0Ra  #AMLT #token #blockchain #ico #AML #regtech @Coinfirm_io
# 133   so much fud about bitcoin for months, but not a word that ethereum is more expensive to transact then bitcoin$ETH & ERC-20 tokens are now in SOS mode.it took $3+ for me to make a transaction.@coindesk @wsj @ForbesCrypto @bloombergpic.twitter.com/ri8Fowuk2j
# 138   #Startup @gladiusIO fights #DDoS using the #blockchain: https://magazine.startus.cc/startup-gladius-fights-ddos-using-the-blockchain/ … #interview #security #ethereum
# 154   Gladius is an ICO, which aims to change the way DDoS attacks are managed. Dont forget to follow us on: Telegram: http://t.me/gladiusio  Facebook: https://facebook.com/gladiusio  Medium: https://medium.com/@gladiusio #ICO #Token #TokenSale #Blockchain #Cryptocurrency #Bitcoinpic.twitter.com/aWiYCN2SoD
# 167   Cybersecurity is a Mess; Can Blockchains Fix It? - https://www.infosecurity-magazine.com/next-gen-infosec/cybersecurity-mess-blockchains-fix/ …#ICO #Token #TokenSale #Blockchain #Cryptocurrency #Bitcoin #Ethereum #Startup #Business #DDoS #Security #BigData #Fintech #Technology #Iota
# 173   10 major cyber attacks in the history of mankindhttps://medium.com/@LevelNetwork/10-major-cyber-attacks-in-the-history-of-mankind-cd6d53f5361c …#blockchain #bitcoin #ethereum #cryptocurrency #ico #levelnet #cybersecurity #crypto #crowdfunding #crowdsale #tokensale #antivirus #investing #startup #token #whitepaper #btc #eth
# 180   That #CryptoKitties $eth game is rising, but also causing bad performance of the #Ethereum #blockchain$eth investors won't be happy :) Please move that game to $strat sidechain when it's released, as #Ethereum blockchain IS NOT #scalable!A happy #Stratis investor$btc $xrp
# 197   There are still #CROM #Token available in our initial token distribution round!This round only lasts until on Dec 15th. After this, CROM tokens are only available without the 25% bonus. Secure your CROM tokens now directly from @CROMhub. #tokensale #ecommerce #Bitcoin #Ethereumpic.twitter.com/ow5rl0eToa
# 212   413.875.795 BNK out of 7.500.000.000 BNK distributed so far. Don't miss a chance to get your tokens while the price is still 0.017 EUR! #blockchain #ICO #cryptocurrency #TokenSalepic.twitter.com/6mvXZaJmvb
# 220   By the way, with REGA Crowdsurance blockchain platform you will be able to cover risks of flight delays or luggage loss! https://www.rega.life/ https://www.youtube.com/watch?v=xbNPXPaH-Fs …#cryptocurrency #Ethereum #ETH #blockchain #cryptoavia
# 241   waiting $XLR adding new feature. algo change completed, old nist5 chain is dead. now xevan chain is working and daily supply halfed! zXLR coming this month. zerocoin protocol in @SolarisCoin will be amazing.x10 is quite possible in my opinion.masternodes FTW! $BTC $ETH $RHOC $LTCpic.twitter.com/9AGaUrUyEy
# 242   Kitties!!! On the BBC! #Ethereum @bchaininsider CryptoKitties craze slows down transactions on Ethereum - BBC Newshttp://www.bbc.com/news/technology-42237162 …
# 249   Kittens are killing @ethereumproject;) what now @VitalikButerin ?#ethereum #eth #bitcoin #btc #blockchain #CryptoKittenspic.twitter.com/tm8rTiknlc
# 281   The projects today are building the foundation for future blockchain tech. Don’t miss out on the largest returns. DYOR. $BTC $ETH $WTC
# 282   I am going to give a homeless person a 20 tomorrow. I feel terrible for buying a cryptokittie $ETH
# 285   Not looking great here for $ETH pic.twitter.com/2MTwmIGMvV
# 286   I Died!! #Ethereum #Cryptokitties #EOS @VitalikButerin @EOS_io #Catspic.twitter.com/ZaR0Y455YJ
# 334   .@bitfinex #ethereum hot wallet just got emptied in one transaction. https://etherscan.io/address/0x1151314c646ce4e0efd76d1af4760ae66a9fe30f …
# ...                                                                                                                                              ...
# 3422  the problem as @petertoddbtc pointed out, is that the Bitcoin ecosystem is sufficiently complex, that journalists get bamboozled by charlatans and shady pump & dump types. also respectable people tend to be heads down doing things and so not quite as accessible. also drama sells.
# 3424  they have opinions & are frustrated as they should be listened to, despite not being quite clueful on fundamentals about tech, economics, biz - so they write r/btc fan-fiction, pay for astroturfing, talk on podcasts that will give them airtime & use Bill O'reilly argument style.https://twitter.com/petertoddbtc/status/931552259292442626 …
# 3438  #Dash announces new partnership, 2 MB blocks activate.https://cointelegraph.com/news/dash-aims-for-mass-adoption-announces-new-integration-activates-2-mb-blocks …
# 3458  #Uber hacked in 2016 for mobile numbers, names - your #BTC wallet may be at risk.https://cointelegraph.com/news/uber-hacked-user-data-compromised-wallets-at-risk …
# 3509  In case you missed it - Q&A session summary with $WAVES PM Alex Kofman published -> http://wavescommunity.com/alex-kofman-qa-summary/ … #wavesplatform #WavesGoesNG #WavesQApic.twitter.com/ONHO0A6pkS
# 3520  "#WAX Drastically Lowers the Cost in Setting Up a #VirtualAsset Exchange…to Zero." Read the full post here: https://buff.ly/2zqaXpm pic.twitter.com/m4BN028UlT
# 3521  No one is a "Bitcoin millionaire" unless they own a million BTC.pic.twitter.com/xk2tVyPhBH
# 3525  This is an embarrassingly misleading graph from @WSJ. Why only show one year of #bitcoin market data when you could show the last 6+ yrs and more fairly make a comparison?pic.twitter.com/4uadfU8VRe
# 3528  The crypto asset social media sphere is a giant never-ending shareholder meeting with no agenda, no code of conduct, and no board of directors.
# 3532  Bitcoin has been declared dead 200 times. Long live Bitcoin!https://99bitcoins.com/obituary-stats/
# 3535  One of the most damaging and widespread social beliefs is the idea that most adults are incapable of learning new skills.
# 3542  Sexual abuse curb: What about ‘chipping’ all penises with a geo-app that alerts everyone (including police and employers) whenever any man has a boner.
# 3544  Didn’t know @HowardStern was a bigoted f***.  Stick with the dick jokes asshole. Leave the political commentary to pros.
# 3545  Bitcoin is a lesson in personal responsibility; ignorance is negligence. Learn from cryptohistory and other people's mistakes or risk getting rekt.
# 3546  Loss of ‘Net Neutrality’ means US government will be able to throttle traffic to #Bitcoin exchanges (timed with Jamie’s #Bitcoin-futures attacks). P2P exchanges need to launch QUICK.
# 3547  Loss of ‘Net Neutrality’ means ISP’s can throttle traffic to any site. And fuckwit Americans will demand throttling any news source countering the war and bank bailout propaganda.
# 3549  There's no stop loss order that can stop your loss if a crypto asset exchange is compromised. 'Tis safer to HODL than to FODL.
# 3551  Dash Hits USD Record $570 On 2MB Block Upgrade, Zimbabwe Deal https://cointelegraph.com/news/dash-hits-usd-record-570-on-2mb-block-upgrade-zimbabwe-deal … via @Cointelegraph
# 3559  Be fearful when people are greedy and greedy when people are fearful.
# 3561  Creating a new internet is all the rage these days.pic.twitter.com/LUOK3odX99
# 3562  If any Crypto company wants to pay me to be your official Twitter shitposter, my DMs are open.
# 3563  Kraken's dedicated tweeter is killing it.https://twitter.com/MarcHochstein/status/933162837878419456 …
# 3564  COINBASE LOST BTC IN BITFINEX HACK.pic.twitter.com/wkVjpJImMO
# 3566  Unfortunately this is not Ethereum.
# 3576  2017 was the year #cryptocurrencies shook the world’s markets, but what does the future hold in 2018? Our Europe MD, @daranda speaks with @MAmdorsky of the @FinancialTimes in today's FT On-Airhttps://goo.gl/fZkQoH
# 3580  Unsurprisingly, @SEC_News is cracking down on fraudulent #ICOshttps://www.bloomberg.com/news/articles/2017-12-04/sec-halts-ico-that-promised-investors-13-fold-profit-in-a-month …
# 3581  "There is no longer any question of whether Ripple has the potential to shake up the world of finance. The only question is just how quickly the Ripple revolution is going to take place." https://nichehunt.com/ripple-why-the-anti-bitcoin-is-loved-by-banks-and-hated-by-the-internet/ … via @niche_hunt
# 3595  BEWARE: Someone's imitating our website! Please be advised that this is not connected to #NEM Foundation in any way. Our official website is https://nem.io FAKE: https://www.mynem.org/
# 3596  Bomb about to drop. Much excitement incoming.
# 3597  "Ready, fire, aim!" - ICOs today.
#
#       Retweet Count   Hashtags  Sentiment
# 3     13.0           #ethereum -0.3987
# 13    18.0           #hodl     -0.4215
# 25    203.0          #airdrop  -0.6588
# 33    15.0           $omg      -0.3404
# 36    247.0          #ether    -0.3707
# 43    8.0            $eth      -0.4404
# 54    45.0           #ico      -0.5267
# 56    12.0           #ethereum -0.0258
# 65    12.0           #crypto   -0.5962
# 82    7.0            #ethereum -0.6597
# 88    2.0            $eth      -0.7668
# 111   2.0            $eth      -0.5229
# 130   374.0          #ico      -0.6908
# 133   12.0           $eth      -0.1752
# 138   6.0            #ethereum -0.4019
# 154   341.0          #ico      -0.3036
# 167   327.0          #token    -0.3612
# 173   119.0          #ico      -0.4404
# 180   6.0            $eth      -0.9361
# 197   48.0           #ethereum -0.1882
# 212   67.0           #ico      -0.0834
# 220   218.0          #eth      -0.5707
# 241   9.0            $eth      -0.2849
# 242   17.0           #ethereum -0.4153
# 249   28.0           #ethereum -0.6597
# 281   2.0            $eth      -0.1531
# 282   3.0            $eth      -0.4767
# 285   3.0            $eth      -0.5096
# 286   106.0          #ethereum -0.6351
# 334   17.0           #ethereum -0.1779
# ...    ...                 ...     ...
# 3422  25.0           NaN       -0.5994
# 3424  18.0           NaN       -0.7430
# 3438  82.0           NaN       -0.2263
# 3458  27.0           NaN       -0.4019
# 3509  61.0           NaN       -0.2960
# 3520  4.0            NaN       -0.1280
# 3521 NaN             NaN       -0.2960
# 3525  194.0          NaN       -0.6597
# 3528 NaN             NaN       -0.4767
# 3532 NaN             NaN       -0.6800
# 3535 NaN             NaN       -0.7548
# 3542  17.0           NaN       -0.6369
# 3544  10.0           NaN       -0.3612
# 3545  135.0          NaN       -0.7269
# 3546  120.0          NaN       -0.3182
# 3547  59.0           NaN       -0.8442
# 3549  59.0           NaN       -0.5994
# 3551  27.0           NaN       -0.4404
# 3559  10.0           NaN       -0.8750
# 3561 NaN             NaN       -0.3400
# 3562 NaN             NaN       -0.1027
# 3563  3.0            NaN       -0.3400
# 3564  1.0            NaN       -0.4648
# 3566 NaN             NaN       -0.3400
# 3576  156.0          NaN       -0.0516
# 3580  167.0          NaN       -0.4939
# 3581 NaN             NaN       -0.4404
# 3595  46.0           NaN       -0.4263
# 3596  23.0           NaN       -0.2732
# 3597  12.0           NaN       -0.4003
#
# [332 rows x 5 columns]
